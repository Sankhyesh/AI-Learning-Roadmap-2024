# %%
from sklearn.datasets import make_classification
import numpy as np
import matplotlib.pyplot as plt

# Generate data
X, y = make_classification(
    n_samples=100, n_features=2, n_informative=1, n_redundant=0,
    n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=15
)

plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def perceptron(X, y):
    w1 = w2 =b = 1
    learning_rate = 0.01
    epochs = 1000
    for j in range(epochs):
        for i in range(X.shape[0]):
            z = w1 * X[i][0] + w2 * X[i][1] + b # f(x) = w1*x1 + w2*x2 + b
            if z * y[i] < 0: # if misclassified
                w1 += learning_rate * y[i] * X[i][0]
                w2 += learning_rate * y[i] * X[i][1]
                b += learning_rate * y[i]
    return w1, w2, b

# %%
w1, w2, b = perceptron(X, y)

# %%
b
# Out:
# np.float64(1.2300000000000002)

# %%
m = -(w1 / w2)
c = -(b / w2)

print("Slope:", m, "Intercept:", c)

x_input = np.linspace(-3, 3, 100)
y_input = m * x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)
plt.ylim(-3, 2)
plt.show()
# Out:
# Slope: -2.196853431511779 Intercept: -2.7050281152724827

# %%
from openai import OpenAI
import os

# Use host.docker.internal to connect to services on host machine
client = OpenAI(
    base_url="http://host.docker.internal:12434/engines/v1",
    api_key='docker' 
)

completion = client.chat.completions.create(
    model="ai/qwen3:0.6B-F16",
    messages=[
        {"role": "system", "content": "understand the data and provide insights"},
        {"role": "user", "content": ""}
    ]
)

print(completion.choices[0].message.content)
# Out:
# Imagine a sunny afternoon at the park, where a little girl plays with her friends, laughing and dancing. Her family is there too—parents and grandparents cheer her on, making every moment a joy. The story highlights how simple, heartfelt interactions can create happiness and bring people together.
